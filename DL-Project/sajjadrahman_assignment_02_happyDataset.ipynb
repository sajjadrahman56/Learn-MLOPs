# %%
pip install keras==2.12.0
# Out:
# Requirement already satisfied: keras==2.12.0 in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from imblearn.over_sampling import SMOTE
import tensorflow as tf
import logging

# %%
df= pd.read_csv("/content/happydata.csv")

# %%
df
# Out:
#      infoavail  housecost  schoolquality  policetrust  streetquality  ëvents  \
# 0            3          3              3            4              2       4
# 1            3          2              3            5              4       3
# 2            5          3              3            3              3       5
# 3            5          4              3            3              3       5
# 4            5          4              3            3              3       5
# ..         ...        ...            ...          ...            ...     ...
# 138          5          3              3            1              3       5
# 139          5          2              3            4              2       5
# 140          5          3              3            4              4       5
# 141          4          3              3            4              4       5
# 142          5          3              2            5              5       5
#
#      happy
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
# ..     ...
# 138      0
# 139      1
# 140      1
# 141      0
# 142      0
#
# [143 rows x 7 columns]

# %% [markdown]
# <font color='green'>### Check Dataset has duplicate values

# %%
duplicates = df[df.duplicated(keep='first')]

# %%
duplicates
# Out:
#      infoavail  housecost  schoolquality  policetrust  streetquality  ëvents  \
# 4            5          4              3            3              3       5
# 21           4          2              3            3              4       4
# 23           4          3              5            5              5       4
# 29           3          3              1            3              3       4
# 35           3          2              4            4              4       5
# 39           5          3              4            3              4       5
# 53           5          1              3            3              4       4
# 54           5          1              3            3              4       4
# 56           5          2              4            3              4       5
# 58           4          3              2            4              3       4
# 66           5          2              4            4              5       5
# 69           4          1              3            4              4       4
# 94           4          1              3            4              4       3
# 103          5          4              4            4              4       5
# 105          5          5              5            5              5       5
# 121          4          2              4            4              4       4
# 133          5          1              5            5              5       5
# 140          5          3              3            4              4       5
#
#      happy
# 4        0
# 21       1
# 23       0
# 29       1
# 35       1
# 39       1
# 53       1
# 54       1
# 56       1
# 58       1
# 66       1
# 69       1
# 94       0
# 103      1
# 105      1
# 121      0
# 133      1
# 140      1

# %% [markdown]
# - Drop duplicates value

# %%
df_no_duplicates = df.drop_duplicates()

# %%
duplicates = df_no_duplicates[df_no_duplicates.duplicated(keep='first')]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [infoavail, housecost, schoolquality, policetrust, streetquality, ëvents, happy]
# Index: []

# %%
df_no_duplicates.shape
# Out:
# (125, 7)

# %%
df_no_duplicates.head(10)
# Out:
#     infoavail  housecost  schoolquality  policetrust  streetquality  ëvents  \
# 0           3          3              3            4              2       4
# 1           3          2              3            5              4       3
# 2           5          3              3            3              3       5
# 3           5          4              3            3              3       5
# 5           5          5              3            5              5       5
# 6           3          1              2            2              1       3
# 7           5          4              4            4              4       5
# 8           4          1              4            4              4       4
# 9           4          4              4            2              5       5
# 10          3          2              3            3              2       3
#
#     happy
# 0       0
# 1       0
# 2       1
# 3       0
# 5       1
# 6       0
# 7       1
# 8       0
# 9       0
# 10      0

# %% [markdown]
# ### Shuffled the values

# %%
df_shuffled = df_no_duplicates.sample(frac=1).reset_index(drop=True)

# %%
df_shuffled.head(10)
# Out:
#    infoavail  housecost  schoolquality  policetrust  streetquality  ëvents  \
# 0          5          2              3            3              4       5
# 1          4          3              3            4              4       4
# 2          5          3              4            4              4       5
# 3          4          2              4            3              2       4
# 4          5          3              4            4              4       4
# 5          5          3              3            3              2       5
# 6          5          2              3            5              5       5
# 7          4          2              4            5              4       3
# 8          3          2              3            3              5       4
# 9          4          5              5            5              1       3
#
#    happy
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
# 5      0
# 6      1
# 7      0
# 8      0
# 9      0

# %%
# Calculate correlation coefficients
correlation_matrix = df.corr()
correlation_with_target = correlation_matrix['happy'].sort_values(ascending=False)

# Print correlation coefficients
print(correlation_with_target)
# Out:
# happy            1.000000
# infoavail        0.312740
# ëvents           0.220729
# streetquality    0.206685
# schoolquality    0.163639
# policetrust      0.113356
# housecost        0.019368
# Name: happy, dtype: float64

# %%
# Split features and target variable
X_with_house = df_shuffled.drop(columns=['happy'])
y = df_shuffled['happy']

# %%
# Drop the "housecost" feature from the dataset as we can see : 0.019
X = X_with_house.drop(columns=['housecost'])

# %%
# Apply data balancing techniques
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Preprocessing steps
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)  # Apply scaling to balanced data

# Split the balanced data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_resampled, test_size=0.3, random_state=42)

# Split the Train data into train, validation sets
X_train_final, X_val, y_train_final, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

class ANNModel:
    def __init__(self, input_shape, optimizer, checkpoint, early_stopping):       # Constructor
        self.input_shape = input_shape
        self.optimizer = optimizer
        self.checkpoint= checkpoint
        self.early_stopping= early_stopping
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        model.add(Dense(64, input_dim=self.input_shape, activation='relu'))  # 1st hidden layer with 64 nodes
        model.add(Dense(32, activation='relu'))  # 2nd hidden layer with 32 nodes
        model.add(Dropout(0.2))  # Adding dropout with 20%
        model.add(Dense(16, activation='relu'))  # 3rd hidden layer with 16 nodes
        model.add(Dense(8, activation='relu'))   # Additional hidden layer with 8 nodes
        model.add(Dense(1, activation='sigmoid'))  # Output layer with 1 node and sigmoid activation for binary classification
        return model

    def compile_model(self):
        self.model.compile(optimizer=self.optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    def train_model(self, X_train, y_train, epochs=10, batch_size=32, validation_data=None):
        history = self.model.fit(X_train, y_train,
                                 epochs=epochs,
                                 batch_size=batch_size,
                                 validation_data=validation_data,
                                 callbacks=[checkpoint, early_stopping])

        return self.model, history


input_shape = 5  # Assuming 13 features

opt = keras.optimizers.SGD(learning_rate=0.001, momentum=0.01, nesterov=False)

early_stopping= keras.callbacks.EarlyStopping(
    monitor="val_loss",                               # watch validation loss
    min_delta=0,
    patience=5,                                       # patience:  number of epochs with no improvement after which training will be stopped
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0)

checkpoint= keras.callbacks.ModelCheckpoint(
    'ANNmodel_weights.h5',                            # a file will be saved in h5 format
    monitor="val_loss",
    verbose=0,
    save_best_only=True,                              # will save the model weights only when the val_loss  has improved from the previous best value
    save_weights_only=False,                           # only the weights of the model will be saved, rather than saving the entire model
    mode="auto",
    save_freq="epoch",
    initial_value_threshold=None,
)


# Create ANN model object
ann_model = ANNModel(input_shape= input_shape, optimizer= opt,checkpoint= checkpoint, early_stopping=early_stopping)

# Compile the model
ann_model.compile_model()

# Train the model
trained_model, history = ann_model.train_model(X_train, y_train,
                                               epochs=250, batch_size=8, validation_data=(X_test, y_test))
# Out:
# Epoch 1/250
# 11/11 [==============================] - 1s 22ms/step - loss: 0.6911 - accuracy: 0.4886 - val_loss: 0.6917 - val_accuracy: 0.5263
# Epoch 2/250
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6963 - accuracy: 0.4886 - val_loss: 0.6914 - val_accuracy: 0.5263
# Epoch 3/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.6911 - val_accuracy: 0.5263
# Epoch 4/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6947 - accuracy: 0.4886 - val_loss: 0.6908 - val_accuracy: 0.5263
# Epoch 5/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6905 - val_accuracy: 0.5263
# Epoch 6/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.
250
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6712 - accuracy: 0.6250 - val_loss: 0.6701 - val_accuracy: 0.7105
# Epoch 166/250
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6668 - accuracy: 0.6364 - val_loss: 0.6700 - val_accuracy: 0.7105
# Epoch 167/250
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6660 - accuracy: 0.6250 - val_loss: 0.6699 - val_accuracy: 0.7105
# Epoch 168/250
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6736 - accuracy: 0.5795 - val_loss: 0.6698 - val_accuracy: 0.7105
# Epoch 169/250
# 11/11 [==============================] - 0s 12ms/step - loss: 0.6675 - accuracy: 0.6250 - val_loss: 0.6698 - val_accuracy: 0.7105
# Epoch 170/250
# 11/11 [==============================] - 0s 12ms/step - loss: 0.6731 - accuracy: 0.6023 - val_loss: 0.6697 - val_accuracy: 0.7105
# Epoch 171/250
# 11/11 [==============================] - 0s 15ms/step - loss: 0.6684 - accuracy: 0.6364 - val_loss: 0.6696 - val_accuracy: 0.7105
# Epoch 172/250
# 11/11 [==============================] - 0s 24ms/step - loss: 0.6612 - accuracy: 0.6705 - val_loss: 0.6695 - val_accuracy: 0.7105
# Epoch 173/250
# 11/11 [==============================] - 0s 17ms/step - loss: 0.6657 - accuracy: 0.6591 - val_loss: 0.6694 - val_accuracy: 0.7105
# Epoch 174/250
# 11/11 [==============================] - 0s 21ms/step - loss: 0.6718 - accuracy: 0.6136 - val_loss: 0.6693 - val_accuracy: 0.7105
# Epoch 175/250
# 11/11 [==============================] - 0s 17ms/step - loss: 0.6750 - accuracy: 0.6364 - val_loss: 0.6693 - val_accuracy: 0.7105
# Epoch 176/250
# 11/11 [==============================] - 0s 16ms/step - loss: 0.6677 - accuracy: 0.6705 - val_loss: 0.6692 - val_accuracy: 0.7105
# Epoch 177/250
# 11/11 [==============================] - 0s 25ms/step - loss: 0.6791 - accuracy: 0.5682 - val_loss: 0.6692 - val_accuracy: 0.7105
# Epoch 178/250
# 11/11 [==============================] - 0s 21ms/step - loss: 0.6646 - accuracy: 0.6477 - val_loss: 0.6691 - val_accuracy: 0.6842
# Epoch 179/250
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6739 - accuracy: 0.5795 - val_loss: 0.6690 - val_accuracy: 0.6842
# Epoch 180/250
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6661 - accuracy: 0.6250 - val_loss: 0.6690 - val_accuracy: 0.6842
# Epoch 181/250
# 11/11 [==============================] - 0s 24ms/step - loss: 0.6673 - accuracy: 0.6136 - val_loss: 0.6689 - val_accuracy: 0.6842
# Epoch 182/250
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6767 - accuracy: 0.5568 - val_loss: 0.6688 - val_accuracy: 0.6842
# Epoch 183/250
# 11/11 [==============================] - 0s 31ms/step - loss: 0.6711 - accuracy: 0.6136 - val_loss: 0.6687 - val_accuracy: 0.6842
# Epoch 184/250
# 11/11 [==============================] - 0s 27ms/step - loss: 0.6712 - accuracy: 0.6136 - val_loss: 0.6686 - val_accuracy: 0.6842
# Epoch 185/250
# 11/11 [==============================] - 0s 24ms/step - loss: 0.6669 - accuracy: 0.6932 - val_loss: 0.6685 - val_accuracy: 0.6842
# Epoch 186/250
# 11/11 [==============================] - 0s 32ms/step - loss: 0.6682 - accuracy: 0.6023 - val_loss: 0.6684 - val_accuracy: 0.6842
# Epoch 187/250
# 11/11 [==============================] - 0s 17ms/step - loss: 0.6690 - accuracy: 0.7045 - val_loss: 0.6684 - val_accuracy: 0.6842
# Epoch 188/250
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6720 - accuracy: 0.6250 - val_loss: 0.6683 - val_accuracy: 0.6842
# Epoch 189/250
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6706 - accuracy: 0.5568 - val_loss: 0.6682 - val_accuracy: 0.6842
# Epoch 190/250
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6700 - accuracy: 0.5795 - val_loss: 0.6682 - val_accuracy: 0.6842
# Epoch 191/250
# 11/11 [==============================] - 0s 25ms/step - loss: 0.6657 - accuracy: 0.6136 - val_loss: 0.6680 - val_accuracy: 0.6842
# Epoch 192/250
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6668 - accuracy: 0.6932 - val_loss: 0.6680 - val_accuracy: 0.6842
# Epoch 193/250
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6645 - accuracy: 0.6705 - val_loss: 0.6679 - val_accuracy: 0.6842
# Epoch 194/250
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6677 - accuracy: 0.6477 - val_loss: 0.6678 - val_accuracy: 0.6842
# Epoch 195/250
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6631 - accuracy: 0.6477 - val_loss: 0.6678 - val_accuracy: 0.6842
# Epoch 196/250
# 11/11 [==============================] - 0s 12ms/step - loss: 0.
# 11/11 [==============================] - 0s 15ms/step - loss: 0.6666 - accuracy: 0.6364 - val_loss: 0.6658 - val_accuracy: 0.6842
# Epoch 226/250
# 11/11 [==============================] - 0s 25ms/step - loss: 0.6593 - accuracy: 0.6250 - val_loss: 0.6657 - val_accuracy: 0.6842
# Epoch 227/250
# 11/11 [==============================] - 0s 23ms/step - loss: 0.6634 - accuracy: 0.6477 - val_loss: 0.6657 - val_accuracy: 0.6842
# Epoch 228/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6595 - accuracy: 0.6250 - val_loss: 0.6657 - val_accuracy: 0.6842
# Epoch 229/250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6692 - accuracy: 0.6364 - val_loss: 0.6655 - val_accuracy: 0.6842
# Epoch 230/250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6609 - accuracy: 0.6477 - val_loss: 0.6655 - val_accuracy: 0.6842
# Epoch 231/250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6594 - accuracy: 0.6477 - val_loss: 0.6655 - val_accuracy: 0.6842
# Epoch 232/250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6620 - accuracy: 0.6477 - val_loss: 0.6654 - val_accuracy: 0.6842
# Epoch 233/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6574 - accuracy: 0.6591 - val_loss: 0.6653 - val_accuracy: 0.6842
# Epoch 234/250
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6696 - accuracy: 0.6477 - val_loss: 0.6652 - val_accuracy: 0.6842
# Epoch 235/250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6597 - accuracy: 0.6477 - val_loss: 0.6652 - val_accuracy: 0.6842
# Epoch 236/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6588 - accuracy: 0.6705 - val_loss: 0.6651 - val_accuracy: 0.6842
# Epoch 237/250
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6686 - accuracy: 0.6250 - val_loss: 0.6650 - val_accuracy: 0.6842
# Epoch 238/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6634 - accuracy: 0.6136 - val_loss: 0.6649 - val_accuracy: 0.6842
# Epoch 239/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6647 - accuracy: 0.6250 - val_loss: 0.6648 - val_accuracy: 0.6842
# Epoch 240/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6601 - accuracy: 0.6250 - val_loss: 0.6648 - val_accuracy: 0.6842
# Epoch 241/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6675 - accuracy: 0.5568 - val_loss: 0.6647 - val_accuracy: 0.6842
# Epoch 242/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6666 - accuracy: 0.6364 - val_loss: 0.6646 - val_accuracy: 0.6842
# Epoch 243/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6582 - accuracy: 0.5795 - val_loss: 0.6646 - val_accuracy: 0.6842
# Epoch 244/250
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6619 - accuracy: 0.6477 - val_loss: 0.6645 - val_accuracy: 0.6842
# Epoch 245/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6604 - accuracy: 0.6591 - val_loss: 0.6644 - val_accuracy: 0.6842
# Epoch 246/250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6575 - accuracy: 0.6364 - val_loss: 0.6643 - val_accuracy: 0.6842
# Epoch 247/250
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6600 - accuracy: 0.5909 - val_loss: 0.6643 - val_accuracy: 0.6842
# Epoch 248/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6619 - accuracy: 0.6250 - val_loss: 0.6642 - val_accuracy: 0.6842
# Epoch 249/250
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6620 - accuracy: 0.6818 - val_loss: 0.6642 - val_accuracy: 0.6842
# Epoch 250/250
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6588 - accuracy: 0.6705 - val_loss: 0.6641 - val_accuracy: 0.6842

# %%
from sklearn.metrics import f1_score

y_pred = trained_model.predict(X_test)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculate F1 score
f1 = f1_score(y_test, y_pred_binary)
print("F1 Score:", f1)
# Out:
# 2/2 [==============================] - 0s 5ms/step
# F1 Score: 0.6666666666666666

# %%
# Calculate confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_binary)

# %%
cm
# Out:
# array([[14,  6],
#        [ 6, 12]])

# %%
# Plot confusion matrix as heatmap
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Happy', 'Happy'], yticklabels=['Non-Happy', 'Happy'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
